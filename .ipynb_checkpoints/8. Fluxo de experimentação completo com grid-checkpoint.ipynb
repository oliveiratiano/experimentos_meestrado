# %% [markdown]
# ### Importação dos metadados

# %%
from src import transformer
from tqdm import tqdm_notebook as tqdm
import pandas as pd
import nltk
# %load_ext autoreload
# %autoreload 2
df = pd.read_csv("dados/corpus_tratado/metadados.csv")[0:500]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Filtrando os ids por assuntos

# %%
corte = 50
df_validos = pd.DataFrame(df.groupby("Assunto").size()).reset_index()
df_validos.columns = ["assunto", "quant"]
df_validos = df_validos.loc[df_validos.quant >= corte]
display(df_validos.quant.sum())
display(df_validos.assunto.nunique())
documentos_validos = df[df.Assunto.isin(df_validos.assunto)][["id", "Assunto"]].reset_index().drop('index', axis = 1)
diretorio = "dados/corpus_tratado/"
documentos_validos['arquivo'] = documentos_validos.id + '.txt'
documentos_validos['teores'] = [transformer.recuperar_teor(x, diretorio) for x in tqdm(documentos_validos['arquivo'])]
documentos_validos
# Out:
# 60
# 1
# HBox(children=(IntProgress(value=0, max=60), HTML(value='')))
#                            id                Assunto  \
# 0   1000168-07.2019.8.26.0523  Prestação de Serviços
# 1   1010725-31.2018.8.26.0477  Prestação de Serviços
# 2   1000122-42.2018.8.26.0009  Prestação de Serviços
# 3   1009683-62.2019.8.26.0007  Prestação de Serviços
# 4   0004104-97.2019.8.26.0348  Prestação de Serviços
# 5   0004222-73.2019.8.26.0348  Prestação de Serviços
# 6   0004224-43.2019.8.26.0348  Prestação de Serviços
# 7   0004225-28.2019.8.26.0348  Prestação de Serviços
# 8   0004226-13.2019.8.26.0348  Prestação de Serviços
# 9   0004227-95.2019.8.26.0348  Prestação de Serviços
# 10  0004229-65.2019.8.26.0348  Prestação de Serviços
# 11  0004230-50.2019.8.26.0348  Prestação de Serviços
# 12  0004231-35.2019.8.26.0348  Prestação de Serviços
# 13  0004232-20.2019.8.26.0348  Prestação de Serviços
# 14  0004233-05.2019.8.26.0348  Prestação de Serviços
# 15  0004266-92.2019.8.26.0348  Prestação de Serviços
# 16  0004267-77.2019.8.26.0348  Prestação de Serviços
# 17  0004269-47.2019.8.26.0348  Prestação de Serviços
# 18  0004270-32.2019.8.26.0348  Prestação de Serviços
# 19  0004274-69.2019.8.26.0348  Prestação de Serviços
# 20  0004277-24.2019.8.26.0348  Prestação de Serviços
# 21  0004234-87.2019.8.26.0348  Prestação de Serviços
# 22  0004263-40.2019.8.26.0348  Prestação de Serviços
# 23  0004281-61.2019.8.26.0348  Prestação de Serviços
# 24  0004283-31.2019.8.26.0348  Prestação de Serviços
# 25  0004287-68.2019.8.26.0348  Prestação de Serviços
# 26  0004291-08.2019.8.26.0348  Prestação de Serviços
# 27  0004294-60.2019.8.26.0348  Prestação de Serviços
# 28  0004292-90.2019.8.26.0348  Prestação de Serviços
# 29  0004295-45.2019.8.26.0348  Prestação de Serviços
# 30  0004297-15.2019.8.26.0348  Prestação de Serviços
# 31  0004298-97.2019.8.26.0348  Prestação de Serviços
# 32  0004300-67.2019.8.26.0348  Prestação de Serviços
# 33  0004302-37.2019.8.26.0348  Prestação de Serviços
# 34  0004329-20.2019.8.26.0348  Prestação de Serviços
# 35  0004376-91.2019.8.26.0348  Prestação de Serviços
# 36  0004377-76.2019.8.26.0348  Prestação de Serviços
# 37  0005751-13.2017.8.26.0053  Prestação de Serviços
# 38  0004379-46.2019.8.26.0348  Prestação de Serviços
# 39  0004380-31.2019.8.26.0348  Prestação de Serviços
# 40  0004389-90.2019.8.26.0348  Prestação de Serviços
# 41  0004391-60.2019.8.26.0348  Prestação de Serviços
# 42  0004402-89.2019.8.26.0348  Prestação de Serviços
# 43  0004417-58.2019.8.26.0348  Prestação de Serviços
# 44  0004419-28.2019.8.26.0348  Prestação de Serviços
# 45  0004423-65.2019.8.26.0348  Prestação de Serviços
# 46  0004425-35.2019.8.26.0348  Prestação de Serviços
# 47  0004427-05.2019.8.26.0348  Prestação de Serviços
# 48  0004428-87.2019.8.26.0348  Prestação de Serviços
# 49  0004432-27.2019.8.26.0348  Prestação de Serviços
# 50  0004433-12.2019.8.26.0348  Prestação de Serviços
# 51  0004440-04.2019.8.26.0348  Prestação de Serviços
# 52  0004441-86.2019.8.26.0348  Prestação de Serviços
# 53  0004442-71.2019.8.26.0348  Prestação de Serviços
# 54  0004443-56.2019.8.26.0348  Prestação de Serviços
# 55  0004444-41.2019.8.26.0348  Prestação de Serviços
# 56  0004445-26.2019.8.26.0348  Prestação de Serviços
# 57  0004447-93.2019.8.26.0348  Prestação de Serviços
# 58  1004481-78.2017.8.26.0006  Prestação de Serviços
# 59  1021853-81.2019.8.26.0002  Prestação de Serviços
#
#                           arquivo  \
# 0   1000168-07.2019.8.26.0523.txt
# 1   1010725-31.2018.8.26.0477.txt
# 2   1000122-42.2018.8.26.0009.txt
# 3   1009683-62.2019.8.26.0007.txt
# 4   0004104-97.2019.8.26.0348.txt
# 5   0004222-73.2019.8.26.0348.txt
# 6   0004224-43.2019.8.26.0348.txt
# 7   0004225-28.2019.8.26.0348.txt
# 8   0004226-13.2019.8.26.0348.txt
# 9   0004227-95.2019.8.26.0348.txt
# 10  0004229-65.2019.8.26.0348.txt
# 11  0004230-50.2019.8.26.0348.txt
# 12  0004231-35.2019.8.26.0348.txt
# 13  0004232-20.2019.8.26.0348.txt
# 14  0004233-05.2019.8.26.0348.txt
# 15  0004266-92.2019.8.26.0348.txt
# 16  0004267-77.2019.8.26.0348.txt
# 17  0004269-47.2019.8.26.0348.txt
# 18  0004270-32.2019.8.26.0348.txt
# 19  0004274-69.2019.8.26.0348.txt
# 20  0004277-24.2019.8.26.0348.txt
# 21  0004234-87.2019.8.26.0348.txt
# 22  0004263-40.2019.8.26.0348.txt
# 23  0004281-61.2019.8.26.0348.txt
# 24  0004283-31.2019.8.26.0348.txt
# 25  0004287-68.2019.8.26.0348.txt
# 26  0004291-08.2019.8.26.0348.txt
# 27  0004294-60.2019.8.26.0348.txt
# 28  0004292-90.2019.8.26.0348.txt
# 29  0004295-45.2019.8.26.0348.txt
# 30  0004297-15.2019.8.26.0348.txt
# 31  0004298-97.2019.8.26.0348.txt
# 32  0004300-67.2019.8.26.0348.txt
# 33  0004302-37.2019.8.26.0348.txt
# 34  0004329-20.2019.8.26.0348.txt
# 35  0004376-91.2019.8.26.0348.txt
# 36  0004377-76.2019.8.26.0348.txt
# 37  0005751-13.2017.8.26.0053.txt
# 38  0004379-46.2019.8.26.0348.txt
# 39  0004380-31.2019.8.26.0348.txt
# 40  0004389-90.2019.8.26.0348.txt
# 41  0004391-60.2019.8.26.0348.txt
# 42  0004402-89.2019.8.26.0348.txt
# 43  0004417-58.2019.8.26.0348.txt
# 44  0004419-28.2019.8.26.0348.txt
# 45  0004423-65.2019.8.26.0348.txt
# 46  0004425-35.2019.8.26.0348.txt
# 47  0004427-05.2019.8.26.0348.txt
# 48  0004428-87.2019.8.26.0348.txt
# 49  0004432-27.2019.8.26.0348.txt
# 50  0004433-12.2019.8.26.0348.txt
# 51  0004440-04.2019.8.26.0348.txt
# 52  0004441-86.2019.8.26.0348.txt
# 53  0004442-71.2019.8.26.0348.txt
# 54  0004443-56.2019.8.26.0348.txt
# 55  0004444-41.2019.8.26.0348.txt
# 56  0004445-26.2019.8.26.0348.txt
# 57  0004447-93.2019.8.26.0348.txt
# 58  1004481-78.2017.8.26.0006.txt
# 59  1021853-81.2019.8.26.0002.txt
#
#                                                teores
# 0   i- relatório cgmp - centro de gestao de meios ...
# 1   petição retro o feito encontra-se julgado \nco...
# 2   tendo em vista a liquidação da dívida pela par...
# 3   argenton e queiroz advogados associados ajuizo...
# 4   homologo por sentença para que produza m os se...
# 5   homologo por sentença para que produza m os se...
# 6   homologo por sentença para que produza m os se...
# 7   homologo por sentença para que produza m os se...
# 8   homologo por sentença para que produza m os se...
# 9   homologo por sentença para que produza m os se...
# 10  homologo por sentença para que produza m os se...
# 11  homologo por sentença para que produza m os se...
# 12  homologo por sentença para que produza m os se...
# 13  homologo por sentença para que produza m os se...
# 14  homologo por sentença para que produza m os se...
# 15  homologo por sentença para que produza m os se...
# 16  homologo por sentença para que produza m os se...
# 17  homologo por sentença para que produza m os se...
# 18  homologo por sentença para que produza m os se...
# 19  homologo por sentença para que produza m os se...
# 20  homologo por sentença para que produza m os se...
# 21  homologo por sentença para que produza m os se...
# 22  homologo por sentença para que produza m os se...
# 23  homologo por sentença para que produza m os se...
# 24  homologo por sentença para que produza m os se...
# 25  homologo por sentença para que produza m os se...
# 26  homologo por sentença para que produza m os se...
# 27  homologo por sentença para que produza m os se...
# 28  homologo por sentença para que produza m os se...
# 29  homologo por sentença para que produza m os se...
# 30  homologo por sentença para que produza m os se...
# 31  homologo por sentença para que produza m os se...
# 32  homologo por sentença para que produza m os se...
# 33  homologo por sentença para que produza m os se...
# 34  homologo por sentença para que produza m os se...
# 35  homologo por sentença para que produza m os se...
# 36  homologo por sentença para que produza m os se...
# 37  trata-se de impugnação ao cumprimento de sente...
# 38  homologo por sentença para que produza m os se...
# 39  homologo por sentença para que produza m os se...
# 40  homologo por sentença para que produza m os se...
# 41  homologo por sentença para que produza m os se...
# 42  homologo por sentença para que produza m os se...
# 43  homologo por sentença para que produza m os se...
# 44  homologo por sentença para que produza m os se...
# 45  homologo por sentença para que produza m os se...
# 46  homologo por sentença para que produza m os se...
# 47  homologo por sentença para que produza m os se...
# 48  homologo por sentença para que produza m os se...
# 49  homologo por sentença para que produza m os se...
# 50  homologo por sentença para que produza m os se...
# 51  homologo por sentença para que produza m os se...
# 52  homologo por sentença para que produza m os se...
# 53  homologo por sentença para que produza m os se...
# 54  homologo por sentença para que produza m os se...
# 55  homologo por sentença para que produza m os se...
# 56  homologo por sentença para que produza m os se...
# 57  homologo por sentença para que produza m os se...
# 58  homologo o acordo celebrado entre as partes a ...
# 59  serviço nacional de aprendizagem comercial - s...

# %% [markdown]
# ### cortando documentos curtos

# %%
min_palavras_documento = 50
documentos_validos['validos'] = documentos_validos.teores.apply(lambda x: 0 if len(x.split(' ')) <= min_palavras_documento else 1)
documentos_validos = documentos_validos[documentos_validos['validos'] == 1].drop(['arquivo', 'teores', 'validos'], axis = 1).reset_index().drop('index', axis = 1)
documentos_validos
# Out:
#                            id                Assunto
# 0   1000168-07.2019.8.26.0523  Prestação de Serviços
# 1   1010725-31.2018.8.26.0477  Prestação de Serviços
# 2   1000122-42.2018.8.26.0009  Prestação de Serviços
# 3   1009683-62.2019.8.26.0007  Prestação de Serviços
# 4   0004104-97.2019.8.26.0348  Prestação de Serviços
# 5   0004222-73.2019.8.26.0348  Prestação de Serviços
# 6   0004224-43.2019.8.26.0348  Prestação de Serviços
# 7   0004225-28.2019.8.26.0348  Prestação de Serviços
# 8   0004226-13.2019.8.26.0348  Prestação de Serviços
# 9   0004227-95.2019.8.26.0348  Prestação de Serviços
# 10  0004229-65.2019.8.26.0348  Prestação de Serviços
# 11  0004230-50.2019.8.26.0348  Prestação de Serviços
# 12  0004231-35.2019.8.26.0348  Prestação de Serviços
# 13  0004232-20.2019.8.26.0348  Prestação de Serviços
# 14  0004233-05.2019.8.26.0348  Prestação de Serviços
# 15  0004266-92.2019.8.26.0348  Prestação de Serviços
# 16  0004267-77.2019.8.26.0348  Prestação de Serviços
# 17  0004269-47.2019.8.26.0348  Prestação de Serviços
# 18  0004270-32.2019.8.26.0348  Prestação de Serviços
# 19  0004274-69.2019.8.26.0348  Prestação de Serviços
# 20  0004277-24.2019.8.26.0348  Prestação de Serviços
# 21  0004234-87.2019.8.26.0348  Prestação de Serviços
# 22  0004263-40.2019.8.26.0348  Prestação de Serviços
# 23  0004281-61.2019.8.26.0348  Prestação de Serviços
# 24  0004283-31.2019.8.26.0348  Prestação de Serviços
# 25  0004287-68.2019.8.26.0348  Prestação de Serviços
# 26  0004291-08.2019.8.26.0348  Prestação de Serviços
# 27  0004294-60.2019.8.26.0348  Prestação de Serviços
# 28  0004292-90.2019.8.26.0348  Prestação de Serviços
# 29  0004295-45.2019.8.26.0348  Prestação de Serviços
# 30  0004297-15.2019.8.26.0348  Prestação de Serviços
# 31  0004298-97.2019.8.26.0348  Prestação de Serviços
# 32  0004300-67.2019.8.26.0348  Prestação de Serviços
# 33  0004302-37.2019.8.26.0348  Prestação de Serviços
# 34  0004329-20.2019.8.26.0348  Prestação de Serviços
# 35  0004376-91.2019.8.26.0348  Prestação de Serviços
# 36  0004377-76.2019.8.26.0348  Prestação de Serviços
# 37  0005751-13.2017.8.26.0053  Prestação de Serviços
# 38  0004379-46.2019.8.26.0348  Prestação de Serviços
# 39  0004380-31.2019.8.26.0348  Prestação de Serviços
# 40  0004389-90.2019.8.26.0348  Prestação de Serviços
# 41  0004391-60.2019.8.26.0348  Prestação de Serviços
# 42  0004402-89.2019.8.26.0348  Prestação de Serviços
# 43  0004417-58.2019.8.26.0348  Prestação de Serviços
# 44  0004419-28.2019.8.26.0348  Prestação de Serviços
# 45  0004423-65.2019.8.26.0348  Prestação de Serviços
# 46  0004425-35.2019.8.26.0348  Prestação de Serviços
# 47  0004427-05.2019.8.26.0348  Prestação de Serviços
# 48  0004428-87.2019.8.26.0348  Prestação de Serviços
# 49  0004432-27.2019.8.26.0348  Prestação de Serviços
# 50  0004433-12.2019.8.26.0348  Prestação de Serviços
# 51  0004440-04.2019.8.26.0348  Prestação de Serviços
# 52  0004441-86.2019.8.26.0348  Prestação de Serviços
# 53  0004442-71.2019.8.26.0348  Prestação de Serviços
# 54  0004443-56.2019.8.26.0348  Prestação de Serviços
# 55  0004444-41.2019.8.26.0348  Prestação de Serviços
# 56  0004445-26.2019.8.26.0348  Prestação de Serviços
# 57  0004447-93.2019.8.26.0348  Prestação de Serviços
# 58  1004481-78.2017.8.26.0006  Prestação de Serviços
# 59  1021853-81.2019.8.26.0002  Prestação de Serviços

# %% [markdown]
# ### Execução do fluxo de experimentação

# %%
n_experimentos = 1
lista_k = np.arange(0,10)
grid_minfreqs = [0, 50, 100]
grid_stopwords = [True, False]
grid_ica = [True, False]
grid_tesauro = [True, False]
grid_dimensoes = [100,300]
df = transformer.transform_param(documentos_validos, n_experimentos, grid_minfreqs, grid_stopwords, grid_ica, grid_tesauro, grid_dimensoes, lista_k)
# Out:
# 2021-04-05 01:18:58,983 : INFO : loading projection weights from modelos/100/w2v_skip_nilc.txt
# 2021-04-05 01:20:19,152 : INFO : loaded (929606, 100) matrix from modelos/100/w2v_skip_nilc.txt
# 2021-04-05 01:20:19,153 : INFO : loading projection weights from modelos/100/ftt_skip_nilc.txt
# 2021-04-05 01:21:36,902 : INFO : loaded (929605, 100) matrix from modelos/100/ftt_skip_nilc.txt
# 2021-04-05 01:21:36,903 : INFO : loading projection weights from modelos/100/glove_nilc.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-32d0d9a81d19> in <module>
#       6 grid_tesauro = [True, False]
#       7 grid_dimensoes = [100,300]
# ----> 8 df = transformer.transform_param(documentos_validos, n_experimentos, grid_minfreqs, grid_stopwords, grid_ica, grid_tesauro, grid_dimensoes, lista_k)
#
# D:\Projetos\mestrado\experimentos_mestrado\src\transformer.py in transform_param(documentos_validos, n_experimentos, minfreqs, op_stopwords, op_ica, op_tesauro, op_tam_vec, lista_k)
#     260         for tam_vec in op_tam_vec:
#     261             # importando modelos de domínio geral
# --> 262             w2v_geral, ftt_geral, glv_geral = importar_modelos_nilc(tam_vec)
#     263             for remover_stopwords_pt in op_stopwords:
#     264                 for usar_ica in op_ica:
#
# D:\Projetos\mestrado\experimentos_mestrado\src\transformer.py in importar_modelos_nilc(tam_vec)
#     190     w2v_geral = KeyedVectors.load_word2vec_format('modelos/'+ str(tam_vec) + '/w2v_skip_nilc.txt')
#     191     ftt_geral = KeyedVectors.load_word2vec_format('modelos/'+ str(tam_vec) + '/ftt_skip_nilc.txt')
# --> 192     glv_geral = KeyedVectors.load_word2vec_format('modelos/'+ str(tam_vec) + '/glove_nilc.txt')
#     193
#     194     return(w2v_geral, ftt_geral, glv_geral)
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1547         return _load_word2vec_format(
#    1548             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
# -> 1549             limit=limit, datatype=datatype)
#    1550
#    1551     @classmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, binary_chunk_size)
#     286                 vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size)
#     287         else:
# --> 288             _word2vec_read_text(fin, result, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#     289     if result.vectors.shape[0] != len(result.vocab):
#     290         logger.info(
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\utils_any2vec.py in _word2vec_read_text(fin, result, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#     213 def _word2vec_read_text(fin, result, counts, vocab_size, vector_size, datatype, unicode_errors, encoding):
#     214     for line_no in range(vocab_size):
# --> 215         line = fin.readline()
#     216         if line == b'':
#     217             raise EOFError("unexpected end of input; is count incorrect or file otherwise damaged?")
#
# KeyboardInterrupt:

# %% [markdown]
# ### Treinamento e representação do Doc2Vec

# %%
from gensim.models.doc2vec import Doc2Vec
from sklearn.preprocessing import normalize
import numpy as np
lista_experimentos = np.arange(0,10)
for i in lista_experimentos:
    exp = i+1
    print('--------- Treinando doc2vec do experimento '+ str(exp)+' ---------')
    dir_experimento = 'experimento_'+str(exp)
    corpus="dados/"+dir_experimento+"/base_treino_glv.txt"
    model = Doc2Vec(corpus_file = corpus, vector_size=100, window=5, min_count=1, workers=8)
    model.save("dados/"+dir_experimento+"/doc2vec_jur.model")
    print('--------- Inferindo vetores para docs de teste do experimento '+ str(exp)+' ---------')
    base_teste = pd.read_csv("dados/"+dir_experimento+"/vetores_teste.csv")
    base_teste['doc2vec_jur'] = [normalize(model.infer_vector(x[0].split(' ')).reshape(1,-1)) for x in base_teste.teores]
    base_teste.to_csv('dados/experimento_'+str(exp)+'/vetores_teste.csv', index=False)
# Out:
# --------- Treinando doc2vec do experimento 1 ---------
# --------- Inferindo vetores para docs de teste do experimento 1 ---------
# --------- Treinando doc2vec do experimento 2 ---------
# --------- Inferindo vetores para docs de teste do experimento 2 ---------
# --------- Treinando doc2vec do experimento 3 ---------
# --------- Inferindo vetores para docs de teste do experimento 3 ---------
# --------- Treinando doc2vec do experimento 4 ---------
# --------- Inferindo vetores para docs de teste do experimento 4 ---------
# --------- Treinando doc2vec do experimento 5 ---------
# --------- Inferindo vetores para docs de teste do experimento 5 ---------
# --------- Treinando doc2vec do experimento 6 ---------
# --------- Inferindo vetores para docs de teste do experimento 6 ---------
# --------- Treinando doc2vec do experimento 7 ---------
# --------- Inferindo vetores para docs de teste do experimento 7 ---------
# --------- Treinando doc2vec do experimento 8 ---------
# --------- Inferindo vetores para docs de teste do experimento 8 ---------
# --------- Treinando doc2vec do experimento 9 ---------
# --------- Inferindo vetores para docs de teste do experimento 9 ---------
# --------- Treinando doc2vec do experimento 10 ---------
# --------- Inferindo vetores para docs de teste do experimento 10 ---------
